# %%
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces == ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face
    
cap = cv2.VideoCapture(0)
count = 0

# Collect 200 samples of your face from webcam input
while True:

    ret, photo = cap.read()
    if face_extractor(photo) is not None:
        count += 1
        face = cv2.resize(face_extractor(photo), (200, 200)) #getting the face and changing size of image
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY) #convert colour image to black-white (grayscale)

        # Save file in specified directory with unique name
        file_name_path = 'C:\ML_project\mydataset\\' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        pass

    if cv2.waitKey(1) == 27 or count == 200: #27 is the Esc Key
        break
        
cap.release()
cv2.destroyAllWindows() #upon completion close the window      
print("Collecting Samples Complete")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_58532\2576750028.py:13: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# Collecting Samples Complete

# %%
# model creation

# python -m pip install --user opencv-contrib-python

import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
print(cv2.__version__)
# Get the training data we previously made
data_path = 'C:\ML_project\mydataset\\'
# a=listdir('d:/faces')
# print(a)
# """
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)
# 
# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)
# model=cv2.face_LBPHFaceRecognizer.create()

model = cv2.face.LBPHFaceRecognizer_create() 
# Initialize facial recognizer
#model = cv2.face_LBPHFaceRecognizer.create()
# model=cv2.f
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()

# Let's train our model 
model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained successfully")
# Out:
# 4.7.0
# Model trained successfully

# %%
#prediciton


import cv2
import numpy as np
import os
import urllib.request

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):

    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()

    image, face = face_detector(frame)

    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = model.predict(face)
        print(results)
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'

        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)

        if confidence > 80:
           
            cv2.putText(image, "Welcome Sonam!!", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            
            #os.system("curl /kxzehhlpr5.execute-api.ap-south-1.amazonaws.com/test/unlock")
            
            #AI MODEL
            request_url = urllib.request.urlopen("https://j26fhw0pq2.execute-api.ap-south-1.amazonaws.com/test/unlock")
            print( request_url.read())
            
            cv2.imshow('Face Recognition', image )
          

        else:
            cv2.putText(image, "i dont know", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)

            
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass

    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# <>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\hp\AppData\Local\Temp\ipykernel_58532\3806979602.py:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# (0, 51.07840716857931)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 36.42873006167171)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 26.368980898222567)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 26.498848361004125)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (81, 27.786749463637996)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (77, 34.868161970068115)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (80, 39.49356069555648)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (80, 35.626941151563)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (82, 28.261165348347085)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (109, 28.798961210069645)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (90, 27.304958790972716)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (90, 27.85853162760866)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (110, 26.135926656757977)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (98, 24.76532594308848)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (92, 28.33366670322717)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 27.066153505486117)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 26.355926210905384)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 26.74413604025003)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 23.732514960958007)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 31.559810233410758)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 30.292851404610442)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 29.066437980878412)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 24.421710001993546)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 25.057301097999453)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 26.081129972728128)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 26.055143887279176)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (96, 26.28229638910646)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (97, 26.798415673795727)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (101, 25.603542889781146)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (96, 22.0827648468726)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 24.757341801895247)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (92, 23.244724746753818)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (95, 24.733487120692516)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 23.747369185774392)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 24.088579784832834)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 25.555013395106084)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 25.71805453543298)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 25.950328322656674)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 26.55322248672516)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 27.27040392053689)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 25.553126576233893)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 26.906959896658943)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 25.96525383368245)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 27.737444821323763)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 25.229531121436814)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 25.481241457848)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (95, 27.843012694563562)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (95, 24.743535687917483)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 24.041260208251007)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 23.73963518055401)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (70, 24.982207163377836)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 25.642648542065487)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (70, 24.850623766375985)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 25.364420510815485)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (70, 27.26205977020257)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 25.711161380742173)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 27.65136059306531)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.160078333051317)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 26.662055966927852)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 25.812251477458883)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 28.923622526429117)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 28.257399522134353)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 25.717834247201644)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 27.527661032576226)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 27.817678229299215)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 26.589442836575557)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.824527867754046)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 28.08447846257888)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 28.190431130768772)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 24.55824142596359)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 24.583381763789404)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (61, 26.347794904146816)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (58, 25.099265783307665)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 27.30206272754451)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 25.969926303181328)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.40662956314284)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.46600464420004)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 23.992048668275327)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (123, 35.65025779227596)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (108, 25.82596499802413)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (113, 26.80767580781686)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 25.476071864396523)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 30.071443310091556)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 28.927542583401216)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 29.790361289678575)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 31.671815322893117)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 31.720046197770657)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (90, 32.6833175871836)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 29.555167089445955)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 31.625630524013584)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 30.68864257649514)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 31.556470701353334)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 35.44831877977382)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 32.661082470145246)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 34.66831364262404)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 26.469893229890737)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 32.76174740215058)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 26.999378171898407)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 29.103393590065746)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 34.77021645845016)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 34.051122144748845)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 32.68111726176107)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (58, 32.94156467581934)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 30.965326206413323)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 33.953352611204764)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (91, 31.348315409599703)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (55, 33.394109701792516)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 29.82654462457347)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 29.722874884088622)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 32.41672166612997)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 28.112192066012856)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 30.367998967168386)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 25.484897377057173)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 26.43152952636569)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (96, 26.271191995951426)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (113, 27.379615148128703)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 27.95144105877761)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 24.72040257458141)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 23.55674860690567)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 23.97169420958089)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 25.191822809651136)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 25.314697833968285)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (49, 28.82801758702624)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 25.28670503369208)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 26.86489827304684)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (173, 34.65617816741069)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 33.97111771442195)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 29.425252215678224)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 30.74123100959708)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 27.421238618907864)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 28.213240048928764)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 29.048905494580527)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.308436744428956)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (24, 24.71159367209169)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (173, 38.845051859332266)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 30.846674872779307)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 26.868163703904514)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 29.28761388965628)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 25.938158434344803)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (108, 33.94311289359759)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (109, 36.22876392306769)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (70, 36.69231777452287)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (63, 36.588718107423865)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 36.89686797490075)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 45.29462122394579)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 36.444766715263036)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (173, 39.81779554171888)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 36.02980658744805)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 43.635356640523625)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 37.21292726614036)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (86, 59.65624213748948)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (82, 52.67990208826602)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (92, 52.36142526472317)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (109, 39.738141197009256)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (63, 36.5589061644165)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (102, 51.673497066532235)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (25, 40.123682768015996)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (61, 36.65008044855932)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (61, 42.69071715144284)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (63, 50.539956781639404)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 50.803272200770536)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (63, 47.035902647183256)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 41.42792382404298)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (25, 37.43040979290984)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 43.38981610234369)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 41.273256466833686)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (61, 41.305813146350175)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 39.65453933990685)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 33.707326707067885)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (59, 34.033393633689734)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 34.41118721313059)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 37.528991739773)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 41.607026061252185)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 31.74681391015546)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 32.08387603863393)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (55, 32.94357188187668)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (43, 30.659403630850786)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (8, 29.279068389952645)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (63, 50.09755075157452)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 41.9515960947713)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (63, 47.02055830664872)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 44.902372870848254)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 42.67082550266424)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 36.23259602693436)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 40.94504272548592)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (61, 43.56649333200159)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 43.92488895439408)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (61, 43.00277367697839)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (62, 52.101716840881636)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 42.68198825271901)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 38.51993744333947)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 39.196924807520794)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 37.86883873914672)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 37.993233160790325)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 39.16637939987825)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (64, 37.99582677865531)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 38.44494372479716)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (24, 39.01781843054816)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (45, 44.56457784901802)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (89, 37.875484112452504)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (65, 37.44379760341013)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (109, 35.85815484764635)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.265785335042168)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (38, 23.44788537773661)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (49, 25.780521944014165)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (9, 26.659115889860534)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (6, 26.82826185598253)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (196, 29.212632262601364)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (7, 31.078458602047373)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 34.526674837433795)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 31.161422848228305)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (8, 37.7014087575942)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (51, 33.98964729415412)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 35.73828822818229)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 29.56096637401038)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 23.521008844245607)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (60, 26.832651335377747)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (66, 28.4545204282044)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (25, 39.23284720703288)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 31.32470092072174)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (109, 30.280935732999737)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 32.265414990004224)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (68, 33.115402340192105)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (22, 33.04196917834007)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (49, 32.51487168689931)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (173, 27.979917949918423)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (49, 27.78070626419295)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (6, 27.790008593295255)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (8, 28.75723498929329)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (188, 33.74651221235302)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (166, 28.85345058216376)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
